# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Batik.csv')

# %%
df.head()
# Out:
#                     path   energi0  homogenitas0  entropy0     contras0  \
# 0  batik\image_00001.jpg  0.007198   1905.733944  6.838876  1904.733944
# 1  batik\image_00002.jpg  0.007198   1905.733944  6.838876  1904.733944
# 2  batik\image_00003.jpg  0.007198   1905.733944  6.838876  1904.733944
# 3  batik\image_00004.jpg  0.007198   1905.733944  6.838876  1904.733944
# 4  batik\image_00005.jpg  0.007198   1905.733944  6.838876  1904.733944
#
#    energi45  homogenitas45  entropy45    contras45  energi90  homogenitas90  \
# 0  0.005845    2511.014508    6.93901  2510.014508  0.007206    1775.046014
# 1  0.005845    2511.014508    6.93901  2510.014508  0.007206    1775.046014
# 2  0.005845    2511.014508    6.93901  2510.014508  0.007206    1775.046014
# 3  0.005845    2511.014508    6.93901  2510.014508  0.007206    1775.046014
# 4  0.005845    2511.014508    6.93901  2510.014508  0.007206    1775.046014
#
# ...

# %%
df.describe()
# Out:
#            energi0  homogenitas0     entropy0      contras0     energi45  \
# count  2177.000000   2177.000000  2177.000000   2177.000000  2177.000000
# mean      0.001254   1692.663130     8.396562   1691.663130     0.001050
# std       0.005409   2106.007295     0.891736   2106.007295     0.004896
# min       0.000058      7.387795     4.740638      6.387795     0.000057
# 25%       0.000187    187.611651     7.880977    186.611651     0.000148
# 50%       0.000362    827.828187     8.536388    826.828187     0.000323
# 75%       0.000783   2498.083600     9.014948   2497.083600     0.000640
# max       0.180662  10811.988500     9.900778  10810.988500     0.179025
#
#        homogenitas45    entropy45     contras45     energi90  homogenitas90  \
# count    2177.000000  2177.000000   2177.000000  2177.000000    2177.000000
# mean     2088.785633     8.526811   2087.785633     0.001266    1373.275665
# std      2333.004344     0.855577   2333.004344     0.005430    1731.725185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177 entries, 0 to 2176
# Data columns (total 18 columns):
# path              2177 non-null object
# energi0           2177 non-null float64
# homogenitas0      2177 non-null float64
# entropy0          2177 non-null float64
# contras0          2177 non-null float64
# energi45          2177 non-null float64
# homogenitas45     2177 non-null float64
# entropy45         2177 non-null float64
# contras45         2177 non-null float64
# energi90          2177 non-null float64
# homogenitas90     2177 non-null float64
# entropy90         2177 non-null float64
# contras90         2177 non-null float64
# energi135         2177 non-null float64
# homogenitas135    2177 non-null float64
# entropy135        2177 non-null float64
# contras135        2177 non-null float64
# label             2177 non-null object
# dtypes: float64(16), object(2)
# memory usage: 306.2+ KB

# %%
df.corr()
# Out:
#                  energi0  homogenitas0  entropy0  contras0  energi45  \
# energi0         1.000000     -0.058942 -0.348936 -0.058942  0.986259
# homogenitas0   -0.058942      1.000000  0.521620  1.000000 -0.050157
# entropy0       -0.348936      0.521620  1.000000  0.521620 -0.321934
# contras0       -0.058942      1.000000  0.521620  1.000000 -0.050157
# energi45        0.986259     -0.050157 -0.321934 -0.050157  1.000000
# homogenitas45  -0.066377      0.976099  0.541593  0.976099 -0.057531
# entropy45      -0.352379      0.488259  0.993337  0.488259 -0.329649
# contras45      -0.066377      0.976099  0.541593  0.976099 -0.057531
# energi90        0.971191     -0.055539 -0.344253 -0.055539  0.991443
# homogenitas90  -0.045048      0.957750  0.521271  0.957750 -0.037848
# entropy90      -0.334686      0.503636  0.984151  0.503636 -0.314616
# contras90      -0.045048      0.957750  0.521271  0.957750 -0.037848
# energi135       0.981581     -0.050857 -0.331160 -0.050857  0.997879
# ...

# %%
df.cov()
# Out:
#                  energi0  homogenitas0     entropy0      contras0  energi45  \
# energi0         0.000029 -6.714409e-01    -0.001683 -6.714409e-01  0.000026
# homogenitas0   -0.671441  4.435267e+06   979.604204  4.435267e+06 -0.517195
# entropy0       -0.001683  9.796042e+02     0.795193  9.796042e+02 -0.001406
# contras0       -0.671441  4.435267e+06   979.604204  4.435267e+06 -0.517195
# energi45        0.000026 -5.171948e-01    -0.001406 -5.171948e-01  0.000024
# homogenitas45  -0.837648  4.795891e+06  1126.744044  4.795891e+06 -0.657181
# entropy45      -0.001631  8.797695e+02     0.757865  8.797695e+02 -0.001381
# contras45      -0.837648  4.795891e+06  1126.744044  4.795891e+06 -0.657181
# energi90        0.000029 -6.350973e-01    -0.001667 -6.350973e-01  0.000026
# homogenitas90  -0.421970  3.492940e+06   804.968486  3.492940e+06 -0.320910
# entropy90      -0.001621  9.498263e+02     0.785897  9.498263e+02 -0.001379
# ...

# %%
f,axis = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, linewidths=.4, fmt= '.2f',ax=axis)
plt.show()

# %%
data = df[['energi0','homogenitas0', 'entropy0', 'contras0', 'energi45', 'homogenitas45', 'entropy45', 'contras45','energi90','homogenitas90', 'entropy90',	'contras90', 'energi135', 'homogenitas135', 'entropy135', 'contras135',
]].to_numpy()

# %%
print(data)
# Out:
# [[7.19793100e-03 1.90573394e+03 6.83887632e+00 ... 2.74053004e+03
#   6.96029708e+00 2.73953004e+03]
#  [7.19793100e-03 1.90573394e+03 6.83887632e+00 ... 2.74053004e+03
#   6.96029708e+00 2.73953004e+03]
#  [7.19793100e-03 1.90573394e+03 6.83887632e+00 ... 2.74053004e+03
#   6.96029708e+00 2.73953004e+03]
#  ...
#  [1.07636000e-04 7.98884350e+02 9.28896750e+00 ... 9.79955174e+02
#   9.34099188e+00 9.78955174e+02]
#  [1.09441000e-04 5.65956570e+02 9.29745811e+00 ... 1.16679924e+03
#   9.51597457e+00 1.16579924e+03]
#  [1.73734100e-03 4.40467520e+01 6.65630789e+00 ... 5.01191642e+01
#   6.62799625e+00 4.91191642e+01]]

# %%
label = df['label'].to_numpy()

# %%
(df['label'].unique())
# Out:
# array(['batik', 'non batik'], dtype=object)

# %% [markdown]
# # Clasifikasi

# %%
from sklearn.model_selection import train_test_split
train_clasx, test_clasx, train_clasy, test_clasy = train_test_split(data, label, test_size=0.20, random_state=42)

# %%
data[1]
# Out:
# array([7.19793100e-03, 1.90573394e+03, 6.83887632e+00, 1.90473394e+03,
#        5.84524800e-03, 2.51101451e+03, 6.93900974e+00, 2.51001451e+03,
#        7.20618200e-03, 1.77504601e+03, 6.82799473e+00, 1.77404601e+03,
#        5.84210600e-03, 2.74053004e+03, 6.96029708e+00, 2.73953004e+03])

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(train_clasx,train_clasy)
neigh.score(train_clasx, train_clasy)
# Out:
# 0.9977024698449167

# %%
pred_clas = neigh.predict(test_clasx)
print (pred_clas)
pred_clas.shape
# Out:
# ['batik' 'batik' 'non batik' 'non batik' 'batik' 'batik' 'batik'
#  'non batik' 'non batik' 'non batik' 'non batik' 'batik' 'batik'
#  'non batik' 'batik' 'non batik' 'batik' 'batik' 'non batik' 'batik'
#  'non batik' 'batik' 'batik' 'batik' 'batik' 'batik' 'non batik' 'batik'
#  'batik' 'non batik' 'batik' 'batik' 'batik' 'batik' 'batik' 'non batik'
#  'batik' 'batik' 'non batik' 'non batik' 'non batik' 'batik' 'non batik'
#  'batik' 'batik' 'batik' 'batik' 'non batik' 'non batik' 'non batik'
#  'non batik' 'batik' 'non batik' 'batik' 'batik' 'non batik' 'non batik'
#  'non batik' 'non batik' 'non batik' 'batik' 'batik' 'batik' 'batik'
#  'batik' 'batik' 'batik' 'batik' 'non batik' 'non batik' 'non batik'
#  'batik' 'non batik' 'non batik' 'batik' 'non batik' 'batik' 'batik'
#  'batik' 'non batik' 'batik' 'non batik' 'non batik' 'non batik'
#  'non batik' 'non batik' 'batik' 'batik' 'batik' 'batik' 'batik'
#  'non batik' 'non batik' 'non batik' 'non batik' 'non batik' 'batik'
# ...

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(test_clasy,pred_clas)
print(score)
# Out:
# 0.9862385321100917

# %% [markdown]
# from sklearn.metrics import accuracy_score
# score = accuracy_score(test_clasy,pred_clas)
# print(score)

# %%
ax = sns.stripplot(x=test_clasy)
